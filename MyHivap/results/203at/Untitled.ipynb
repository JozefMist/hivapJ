# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
proj = '44Ca'
trg = '159Tb'
cn = '203At'
bf = 0.69
ch = 'xn'
sigr = np.arange(2.01, 3.5, 0.2)
sigr = list(sigr)

# %%
for i in sigr:
    sigr_temp = f'{i:.1f}'
    # d = {}
    # d['sigr' + str(sigr_temp)] = pd.read_csv('data/' + proj + '_' + trg + '_' + cn + '_' + ch + '_' + 'IFUS10' + '_barfac' + str(bf) + '_sigr' + str(sigr_temp) + '.dat', sep='\t')    
    file = []
    data = []
    data = pd.read_csv('data/' + proj + '_' + trg + '_' + cn + '_' + ch + '_' + 'IFUS10' + '_barfac' + str(bf) + '_sigr' + str(sigr_temp) + '.dat', sep='\t')
    # file.append(data) 
    data.append( '')
    print(data)
    # file.append((pd.read_csv('data/' + proj + '_' + trg + '_' + cn + '_' + ch + '_' + 'IFUS10' + '_barfac' + str(bf) + '_sigr' + str(sigr_temp) + '.dat', sep='\t')))#.melt(id_vars=['E_lab', 'E*/MeV'], var_name='isotope', value_name='CS'))
# Out:
#       E_lab  E*/MeV         197At         198At         199At         200At  \
# 0   167.440    32.0  0.000000e+00  0.000000e+00  0.000000e+00  3.590000e-08
# 1   168.716    33.0  0.000000e+00  0.000000e+00  0.000000e+00  3.190000e-07
# 2   169.993    34.0  0.000000e+00  0.000000e+00  0.000000e+00  2.280000e-06
# 3   171.270    35.0  0.000000e+00  0.000000e+00  0.000000e+00  1.410000e-05
# 4   172.547    36.0  0.000000e+00  0.000000e+00  1.500000e-10  7.840000e-05
# 5   173.823    37.0  0.000000e+00  0.000000e+00  1.730000e-08  3.890000e-04
# 6   175.100    38.0  0.000000e+00  0.000000e+00  7.660000e-07  1.610000e-03
# 7   176.377    39.0  0.000000e+00  0.000000e+00  1.500000e-05  5.100000e-03
# 8   177.653    40.0  0.000000e+00  0.000000e+00  1.450000e-04  1.240000e-02
# 9   178.930    41.0  0.000000e+00  0.000000e+00  8.100000e-04  2.430000e-02
# 10  180.207    42.0  0.000000e+00  0.000000e+00  3.030000e-03  4.060000e-02
# ...

# %%
data
# Out:
# []

# %%
file
# Out:
# [      E_lab  E*/MeV         197At         198At         199At         200At  \
#  0   162.333    28.0  0.000000e+00  0.000000e+00  0.000000e+00  4.430000e-11
#  1   163.609    29.0  0.000000e+00  0.000000e+00  0.000000e+00  3.720000e-09
#  2   164.886    30.0  0.000000e+00  0.000000e+00  0.000000e+00  1.280000e-07
#  3   166.163    31.0  0.000000e+00  0.000000e+00  0.000000e+00  2.380000e-06
#  4   167.440    32.0  0.000000e+00  0.000000e+00  0.000000e+00  2.710000e-05
#  5   168.716    33.0  0.000000e+00  0.000000e+00  0.000000e+00  2.000000e-04
#  6   169.993    34.0  0.000000e+00  0.000000e+00  0.000000e+00  9.530000e-04
#  7   171.270    35.0  0.000000e+00  0.000000e+00  0.000000e+00  2.990000e-03
#  8   172.547    36.0  0.000000e+00  0.000000e+00  8.820000e-09  7.030000e-03
#  9   173.823    37.0  0.000000e+00  0.000000e+00  4.390000e-07  1.380000e-02
#  10  175.100    38.0  0.000000e+00  0.000000e+00  9.060000e-06  2.450000e-02
# ...
