# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pxn_10 = open('data/88Sr_92Mo_180Hg_pxn_IFUS10_barfac0.85.dat', 'r')

# %%
df_pxn10 = pd.read_csv('data/88Sr_92Mo_180Hg_pxn_IFUS10_barfac0.85.dat', sep='\t')

# %%
df_pxn10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   E_lab   65 non-null     float64
#  1   E*/MeV  65 non-null     float64
#  2   173Au   65 non-null     float64
#  3   174Au   65 non-null     float64
#  4   175Au   65 non-null     float64
#  5   176Au   65 non-null     float64
#  6   177Au   65 non-null     float64
#  7   178Au   65 non-null     float64
#  8   179Au   65 non-null     float64
# dtypes: float64(9)
# memory usage: 4.7 KB

# %%
df_pxn10.loc[0]
# Out:
# E_lab     333.524000
# E*/MeV     16.000000
# 173Au       0.000000
# 174Au       0.000000
# 175Au       0.000000
# 176Au       0.000000
# 177Au       0.000000
# 178Au       0.000000
# 179Au       0.000002
# Name: 0, dtype: float64

# %%
df_pxn10
# Out:
#       E_lab  E*/MeV     173Au    174Au  175Au   176Au     177Au         178Au  \
# 0   333.524    16.0  0.000000  0.00000  0.000  0.0000  0.000000  0.000000e+00
# 1   335.481    17.0  0.000000  0.00000  0.000  0.0000  0.000000  0.000000e+00
# 2   337.437    18.0  0.000000  0.00000  0.000  0.0000  0.000000  1.820000e-09
# 3   339.394    19.0  0.000000  0.00000  0.000  0.0000  0.000000  1.020000e-07
# 4   341.350    20.0  0.000000  0.00000  0.000  0.0000  0.000000  3.800000e-06
# ..      ...     ...       ...      ...    ...     ...       ...           ...
# 60  450.916    76.0  0.000001  0.00885  0.219  0.0794  0.001600  0.000000e+00
# 61  452.872    77.0  0.000003  0.01150  0.198  0.0591  0.001060  0.000000e+00
# 62  454.829    78.0  0.000008  0.01450  0.175  0.0437  0.000691  0.000000e+00
# 63  456.785    79.0  0.000018  0.01760  0.153  0.0321  0.000451  0.000000e+00
# 64  458.742    80.0  0.000037  0.02080  0.132  0.0234  0.000293  0.000000e+00
#
#        179Au
# 0   0.000002
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(df_pxn10.iloc[:, 0], df_pxn10.iloc[:, 2:])
plt.title('')
plt.yscale('log')
plt.ylim([1e-5,1e1])
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_pxn10.iloc[:,2:]
# Out:
#        173Au    174Au  175Au   176Au     177Au         178Au     179Au
# 0   0.000000  0.00000  0.000  0.0000  0.000000  0.000000e+00  0.000002
# 1   0.000000  0.00000  0.000  0.0000  0.000000  0.000000e+00  0.000009
# 2   0.000000  0.00000  0.000  0.0000  0.000000  1.820000e-09  0.000044
# 3   0.000000  0.00000  0.000  0.0000  0.000000  1.020000e-07  0.000218
# 4   0.000000  0.00000  0.000  0.0000  0.000000  3.800000e-06  0.001020
# ..       ...      ...    ...     ...       ...           ...       ...
# 60  0.000001  0.00885  0.219  0.0794  0.001600  0.000000e+00  0.000000
# 61  0.000003  0.01150  0.198  0.0591  0.001060  0.000000e+00  0.000000
# 62  0.000008  0.01450  0.175  0.0437  0.000691  0.000000e+00  0.000000
# 63  0.000018  0.01760  0.153  0.0321  0.000451  0.000000e+00  0.000000
# 64  0.000037  0.02080  0.132  0.0234  0.000293  0.000000e+00  0.000000
#
# [65 rows x 7 columns]
